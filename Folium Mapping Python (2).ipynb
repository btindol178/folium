# %%
# !pip install folium

# %%
import folium # look in china
map = folium.Map(location = [38.58,-99.09],zoom_start = 6)
map.save("Map1.html")

# %%
# Add style tilelayer look in china
map = folium.Map(location = [38.58,-99.09],zoom_start = 6,TileLayer="Mapbox Bright")
map.save("Map2.html")

# %%
# Add marker look in china
map = folium.Map(location = [38.28,-99.09],zoom_start = 6,TileLayer="Mapbox Bright")
map.add_child(folium.Marker(location =[38.2,99.1],popup="Hi i am a marker",icon =folium.Icon(color='green')))
map.save("Map3.html")

# %%
# Making a child passing the map into a variable 
map = folium.Map(location = [38.28,-99.09],zoom_start = 6,TileLayer="Mapbox Bright")
fg = folium.FeatureGroup(name="My map")
fg.add_child(folium.Marker(location =[38.2,99.1],popup="Hi i am a marker",icon =folium.Icon(color='green')))
map.add_child(fg)
map.save("Map4.html")

# %%
# Making another variable 
map = folium.Map(location = [38.28,-99.09],zoom_start = 6,TileLayer="Mapbox Bright")
fg = folium.FeatureGroup(name="My map")
fg.add_child(folium.Marker(location =[38.2,99.1],popup="Hi i am a marker",icon =folium.Icon(color='green')))
fg.add_child(folium.Marker(location =[37.2,97.1],popup="Hi i am a marker2",icon =folium.Icon(color='green')))

map.add_child(fg)
map.save("Map5.html")

# %%
# Making another variable 
map = folium.Map(location = [38.28,-99.09],zoom_start = 6,TileLayer="Mapbox Bright")
fg = folium.FeatureGroup(name="My map")

for coordinates in [[38.2,99.1],[37.2,97.1],[36.2,96.1]]:
    fg.add_child(folium.Marker(location =coordinates,popup="Hi i am a marker",icon =folium.Icon(color='green')))

map.add_child(fg)
map.save("Map7.html")

# %%
import pandas as pd

# %%
import pandas as pd
data =pd.read_csv("Volcanoes.txt")
data.head()
# Out:
#    VOLCANX020    NUMBER          NAME       LOCATION            STATUS  \
# 0       509.0  1201-01=         Baker  US-Washington        Historical
# 1       511.0  1201-02-  Glacier Peak  US-Washington  Tephrochronology
# 2       513.0  1201-03-       Rainier  US-Washington  Dendrochronology
# 3       515.0  1201-05-    St. Helens  US-Washington        Historical
# 4       516.0  1201-04-         Adams  US-Washington  Tephrochronology
#
#      ELEV             TYPE TIMEFRAME        LAT         LON
# 0  3285.0  Stratovolcanoes        D3  48.776798 -121.810997
# 1  3213.0    Stratovolcano        D4  48.111801 -121.111000
# 2  4392.0    Stratovolcano        D3  46.869801 -121.751000
# 3  2549.0    Stratovolcano        D1  46.199799 -122.181000
# 4  3742.0    Stratovolcano        D6  46.205799 -121.490997

# %%
# Read a bunch of lon/ lat markers onto map...
data =pd.read_csv("Volcanoes.txt") # load data
lon = list(data["LON"]) # make longitude adn lattitude into list
lat = list(data["LAT"])

# initialize map
map = folium.Map(location = [38.28,-99.09],zoom_start = 6,TileLayer="Mapbox Bright")
#make map fg variable 
fg = folium.FeatureGroup(name="My map")

for lt, ln in zip(lat,lon):
        fg.add_child(folium.Marker(location =[lt,ln],popup="Hi i am a marker",icon =folium.Icon(color='green')))

map.add_child(fg)
map.save("Map8.html")

# %%
# Add another column as popup (Popup needs to be a string)
data =pd.read_csv("Volcanoes.txt") # load data
lon = list(data["LON"]) # make longitude adn lattitude into list
lat = list(data["LAT"])
elev = list(data["ELEV"]) # This normally needs to be a string!!!!!!!!!

# initialize map
map = folium.Map(location = [38.28,-99.09],zoom_start = 6,TileLayer="Mapbox Bright")
#make map fg variable 
fg = folium.FeatureGroup(name="My map")

for lt, ln, el in zip(lat,lon,elev):
        fg.add_child(folium.Marker(location =[lt,ln],popup=el,icon =folium.Icon(color='green')))

map.add_child(fg)
map.save("Map9.html")

# %%
#
data =pd.read_csv("Volcanoes.txt") # load data
lon = list(data["LON"]) # make longitude adn lattitude into list
lat = list(data["LAT"])
elev = list(data["ELEV"]) # This normally needs to be a string!!!!!!!!!

# initialize map
map = folium.Map(location = [38.28,-99.09],zoom_start = 6,TileLayer="Mapbox Bright")
#make map fg variable 
fg = folium.FeatureGroup(name="My map")

for lt, ln, el in zip(lat,lon,elev):
        fg.add_child(folium.Marker(location =[lt,ln],popup=str(el) + " meters" ,icon =folium.Icon(color='green')))

map.add_child(fg)
map.save("Map9.html")

# %%
# Another way of Formatting!
 
data = pandas.read_csv("Volcanoes.txt")
lat = list(data["LAT"])
lon = list(data["LON"])
elev = list(data["ELEV"])
 
html = """<h4>Volcano information:</h4>
Height: %s m
"""
 
map = folium.Map(location=[38.58, -99.09], zoom_start=5, TileLayer="Mapbox Bright")
fg = folium.FeatureGroup(name = "My Map")
 
for lt, ln, el in zip(lat, lon, elev):
    iframe = folium.IFrame(html=html % str(el), width=200, height=100)
    fg.add_child(folium.Marker(location=[lt, ln], popup=folium.Popup(iframe), icon = folium.Icon(color = "green")))
 
 
map.add_child(fg)
map.save("Map_html_popup_simple.html")

# %%
# More formatting  putting link inside of popup!
data = pandas.read_csv("Volcanoes.txt")
lat = list(data["LAT"])
lon = list(data["LON"])
elev = list(data["ELEV"])
name = list(data["NAME"])
html = """
Volcano name:<br>
<a href="https://www.google.com/search?q=%%22%s%%22" target="_blank">%s</a><br>
Height: %s m
"""
 
map = folium.Map(location=[38.58, -99.09], zoom_start=5, TileLayer="Mapbox Bright")
fg = folium.FeatureGroup(name = "My Map")
 
for lt, ln, el, name in zip(lat, lon, elev, name):
    iframe = folium.IFrame(html=html % (name,name, el), width=200, height=100)
    fg.add_child(folium.Marker(location=[lt, ln], popup=folium.Popup(iframe), icon = folium.Icon(color = "green")))
 
map.add_child(fg)
map.save("Map_html_popup_advanced.html")

# %%
# Coloring Points 
# folium does not have custom color scemes for you 
data =pd.read_csv("Volcanoes.txt") # load data
lon = list(data["LON"]) # make longitude adn lattitude into list
lat = list(data["LAT"])
elev = list(data["ELEV"]) # This normally needs to be a string!!!!!!!!!

# Color changing function 
def color_producer(elevation):
    if elevation < 1000:
        return 'green'
    elif 1000 <= elevation < 3000:
        return 'orange'
    else: 
        return 'red'

# initialize map
map = folium.Map(location = [38.28,-99.09],zoom_start = 6,TileLayer="Mapbox Bright")
#make map fg variable 
fg = folium.FeatureGroup(name="My map")

for lt, ln, el in zip(lat,lon,elev):
        fg.add_child(folium.Marker(location =[lt,ln],popup=str(el) + " meters" ,icon =folium.Icon(color=color_producer(el))))

map.add_child(fg)
map.save("Map10.html")

# %%
# GUIDE TO STYLE!!!!!!!!
#dir(folium)

# %%
# Changin point styles 
data =pd.read_csv("Volcanoes.txt") # load data
lon = list(data["LON"]) # make longitude adn lattitude into list
lat = list(data["LAT"])
elev = list(data["ELEV"]) # This normally needs to be a string!!!!!!!!!

# Color changing function 
def color_producer(elevation):
    if elevation < 1000:
        return 'green'
    elif 1000 <= elevation < 3000:
        return 'orange'
    else: 
        return 'red'

# initialize map
map = folium.Map(location = [38.28,-99.09],zoom_start = 6,TileLayer="Mapbox Bright")
#make map fg variable 
fg = folium.FeatureGroup(name="My map")

for lt, ln, el in zip(lat,lon,elev):
        fg.add_child(folium.CircleMarker(location =[lt,ln], radius = 6,popup=str(el) + " meters" ,
        fill_color= color_producer(el),color= 'grey',fill_opacity = 0.7))
    
map.add_child(fg)
map.save("Map11.html")

# %%
# ADDING LAYERS (COROPLETH)
# Changin point styles 
data =pd.read_csv("Volcanoes.txt") # load data

lon = list(data["LON"]) # make longitude adn lattitude into list
lat = list(data["LAT"])
elev = list(data["ELEV"]) # This normally needs to be a string!!!!!!!!!

# Color changing function 
def color_producer(elevation):
    if elevation < 1000:
        return 'green'
    elif 1000 <= elevation < 3000:
        return 'orange'
    else: 
        return 'red'

# initialize map
map = folium.Map(location = [38.28,-99.09],zoom_start = 6,TileLayer="Mapbox Bright")
#make map fg variable 
fg = folium.FeatureGroup(name="My map")

for lt, ln, el in zip(lat,lon,elev):
        fg.add_child(folium.CircleMarker(location =[lt,ln], radius = 6,popup=str(el) + " meters" ,
        fill_color= color_producer(el),color= 'grey',fill_opacity = 0.7))

# adding layer here
fg.add_child(folium.GeoJson(data=open('world.json','r',encoding='utf-8-sig').read()))
map.add_child(fg)
map.save("Map12.html")

# %%
# Adding color to coropleth!
# ADDING LAYERS (COROPLETH)
# Changin point styles 
import json
data =pd.read_csv("Volcanoes.txt") # load data

lon = list(data["LON"]) # make longitude adn lattitude into list
lat = list(data["LAT"])
elev = list(data["ELEV"]) # This normally needs to be a string!!!!!!!!!

# Color changing function 
def color_producer(elevation):
    if elevation < 1000:
        return 'green'
    elif 1000 <= elevation < 3000:
        return 'orange'
    else: 
        return 'red'

# initialize map
map = folium.Map(location = [38.28,-99.09],zoom_start = 6,TileLayer="Mapbox Bright")
#make map fg variable 
fg = folium.FeatureGroup(name="My map")

for lt, ln, el in zip(lat,lon,elev):
        fg.add_child(folium.CircleMarker(location =[lt,ln], radius = 6,popup=str(el) + " meters" ,
        fill_color= color_producer(el),color= 'grey',fill_opacity = 0.7))

# adding layer here
fg.add_child(folium.GeoJson(data= open('world.json','r',encoding='utf-8-sig').read(),style_function=lambda x:{'fillColor':'litchi' if x["properties"]["POP2005"] < 10000000
else 'green' if 10000000<= x['properties']['POP2005'] < 20000000 else 'red'}))


map.add_child(fg)
map.save("Map14.html")

# %%
# Adding layer control 
import json
data =pd.read_csv("Volcanoes.txt") # load data

lon = list(data["LON"]) # make longitude adn lattitude into list
lat = list(data["LAT"])
elev = list(data["ELEV"]) # This normally needs to be a string!!!!!!!!!

# Color changing function 
def color_producer(elevation):
    if elevation < 1000:
        return 'green'
    elif 1000 <= elevation < 3000:
        return 'orange'
    else: 
        return 'red'

# initialize map
map = folium.Map(location = [38.28,-99.09],zoom_start = 6,TileLayer="Mapbox Bright")
#make map fg variable 
fg = folium.FeatureGroup(name="My map")

for lt, ln, el in zip(lat,lon,elev):
        fg.add_child(folium.CircleMarker(location =[lt,ln], radius = 6,popup=str(el) + " meters" ,
        fill_color= color_producer(el),color= 'grey',fill_opacity = 0.7))

# adding layer here
fg.add_child(folium.GeoJson(data= open('world.json','r',encoding='utf-8-sig').read(),style_function=lambda x:{'fillColor':'litchi' if x["properties"]["POP2005"] < 10000000
else 'green' if 10000000<= x['properties']['POP2005'] < 20000000 else 'red'}))

map.add_child(fg)
map.add_child(folium.LayerControl()) # adding layer control THIS TURNS OFF POLYGON AND POINT AT SAME TIME

map.save("Map15.html")

# %%
# Adding layer control for each individual level 
import json
data =pd.read_csv("Volcanoes.txt") # load data

lon = list(data["LON"]) # make longitude adn lattitude into list
lat = list(data["LAT"])
elev = list(data["ELEV"]) # This normally needs to be a string!!!!!!!!!

# Color changing function 
def color_producer(elevation):
    if elevation < 1000:
        return 'green'
    elif 1000 <= elevation < 3000:
        return 'orange'
    else: 
        return 'red'

# initialize map
map = folium.Map(location = [38.28,-99.09],zoom_start = 6,TileLayer="Mapbox Bright")

#make layer control for volcano
fgv = folium.FeatureGroup(name="Volcanoes")

for lt, ln, el in zip(lat,lon,elev):
        fgv.add_child(folium.CircleMarker(location =[lt,ln], radius = 6,popup=str(el) + " meters" ,
        fill_color= color_producer(el),color= 'grey',fill_opacity = 0.7))

# fgp for layer control for population
fgp = folium.FeatureGroup(name="population")
# adding layer here
fgp.add_child(folium.GeoJson(data= open('world.json','r',encoding='utf-8-sig').read(),style_function=lambda x:{'fillColor':'litchi' if x["properties"]["POP2005"] < 10000000
else 'green' if 10000000<= x['properties']['POP2005'] < 20000000 else 'red'}))

# Adding layer control 
map.add_child(fgv)
map.add_child(fgp)

map.add_child(folium.LayerControl()) # adding layer control THIS TURNS OFF POLYGON AND POINT AT SAME TIME

map.save("Map16.html")
